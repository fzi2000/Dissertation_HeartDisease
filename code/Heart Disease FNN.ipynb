# %%
import pandas as pd
import numpy as np
import gradio as gr
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from tensorflow import keras
from tensorflow.keras import layers

# Load your dataset
# Make sure to replace 'your_dataset.csv' with your actual dataset file
data = pd.read_csv('heart_disease.csv')

# Preprocessing
data.fillna(data.mean(), inplace=True)  # Simple imputation for missing values

# Define features and target variable
X = data.drop('target', axis=1)  # Replace 'target' with your target column name
y = data['target']  # Binary target variable (0 for no heart disease, 1 for heart disease)

# Split the dataset into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# Standardize the features
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# %%
# Build the feedforward neural network model
# Build the feedforward neural network model
model = keras.Sequential([
    layers.Input(shape=(X_train.shape[1],)),  # Input layer as a tuple
    layers.Dense(64, activation='relu'),    # Hidden layer 1
    layers.Dense(32, activation='relu'),    # Hidden layer 2
    layers.Dense(1, activation='sigmoid')    # Output layer for binary classification
])

# Compile the model
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

# Train the model
model.fit(X_train, y_train, epochs=100, batch_size=10, validation_split=0.2)

# Risk level classification function
def classify_risk(prob):
    """Classify the risk level based on the predicted probability."""
    if prob > 0.7:
        return 'High Risk'
    elif prob > 0.4:
        return 'Medium Risk'
    else:
        return 'Low Risk'

# Define the prediction function with risk classification
def predict_heart_disease(age, sex, cp, trestbps, chol, fbs, restecg, thalach, exang, oldpeak, slope, ca, thal):
    input_data = np.array([age, sex, cp, trestbps, chol, fbs, restecg, thalach, exang, oldpeak, slope, ca, thal]).reshape(1, -1)
    input_data = scaler.transform(input_data)  # Standardize the input data
    prob = model.predict(input_data)[0][0]  # Get the probability of heart disease
    risk_level = classify_risk(prob)  # Classify the risk level based on the predicted probability

    if prob < 0.5:
        result = "No heart disease present"
    else:
        result = "Heart disease is present"

    # Include the risk percentage in the output
    risk_percentage = round(prob * 100, 2)  # Convert to percentage
    return f"{result}. Risk Level: {risk_level} ({risk_percentage}%)"
# Out:
# Epoch 1/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 5s 45ms/step - accuracy: 0.4188 - loss: 0.7363 - val_accuracy: 0.6279 - val_loss: 0.6818
# Epoch 2/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.6769 - loss: 0.6013 - val_accuracy: 0.6744 - val_loss: 0.5792
# Epoch 3/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.8026 - loss: 0.4920 - val_accuracy: 0.6744 - val_loss: 0.5215
# Epoch 4/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.8250 - loss: 0.4152 - val_accuracy: 0.6744 - val_loss: 0.4924
# Epoch 5/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8150 - loss: 0.3695 - val_accuracy: 0.7209 - val_loss: 0.4785
# Epoch 6/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8703 - loss: 0.3469 - val_accuracy: 0.7209 - val_loss: 0.4771
# Epoch 7/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8628 - loss: 0.3249 - val_accuracy: 0.7209 - val_loss: 0.4875
# Epoch 8/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8632 - loss: 0.2813 - val_accuracy: 0.7442 - val_loss: 0.4961
# Epoch 9/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9113 - loss: 0.2360 - val_accuracy: 0.7209 - val_loss: 0.5027
# Epoch 10/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9137 - loss: 0.2348 - val_accuracy: 0.7209 - val_loss: 0.5157
# Epoch 11/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8957 - loss: 0.2428 - val_accuracy: 0.7442 - val_loss: 0.5288
# Epoch 12/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9155 - loss: 0.2528 - val_accuracy: 0.7209 - val_loss: 0.5307
# Epoch 13/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9322 - loss: 0.2193 - val_accuracy: 0.7442 - val_loss: 0.5470
# Epoch 14/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8958 - loss: 0.2301 - val_accuracy: 0.7442 - val_loss: 0.5532
# Epoch 15/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9386 - loss: 0.1601 - val_accuracy: 0.7442 - val_loss: 0.5665
# Epoch 16/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9253 - loss: 0.1680 - val_accuracy: 0.7442 - val_loss: 0.5739
# Epoch 17/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9614 - loss: 0.1558 - val_accuracy: 0.7442 - val_loss: 0.5950
# Epoch 18/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9460 - loss: 0.1613 - val_accuracy: 0.7442 - val_loss: 0.5997
# Epoch 19/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9428 - loss: 0.1905 - val_accuracy: 0.7442 - val_loss: 0.6128
# Epoch 20/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9265 - loss: 0.1578 - val_accuracy: 0.6977 - val_loss: 0.6233
# Epoch 21/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9796 - loss: 0.1288 - val_accuracy: 0.7209 - val_loss: 0.6366
# Epoch 22/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9568 - loss: 0.1601 - val_accuracy: 0.7209 - val_loss: 0.6566
# Epoch 23/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9816 - loss: 0.1059 - val_accuracy: 0.6977 - val_loss: 0.6647
# Epoch 24/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9814 - loss: 0.0974 - val_accuracy: 0.6977 - val_loss: 0.6883
# Epoch 25/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9873 - loss: 0.1142 - val_accuracy: 0.6744 - val_loss: 0.6984
# Epoch 26/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9771 - loss: 0.1120 - val_accuracy: 0.6744 - val_loss: 0.7110
# Epoch 27/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9592 - loss: 0.1405 - val_accuracy: 0.6977 - val_loss: 0.7346
# Epoch 28/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9770 - loss: 0.1055 - val_accuracy: 0.6977 - val_loss: 0.7526
# Epoch 29/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9799 - loss: 0.0822 - val_accuracy: 0.6744 - val_loss: 0.7630
# Epoch 30/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9709 - loss: 0.0955 - val_accuracy: 0.6744 - val_loss: 0.7801
# Epoch 31/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9807 - loss: 0.0840 - val_accuracy: 0.6744 - val_loss: 0.7998
# Epoch 32/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9782 - loss: 0.0874 - val_accuracy: 0.6512 - val_loss: 0.8137
# Epoch 33/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9876 - loss: 0.0663 - val_accuracy: 0.6744 - val_loss: 0.8403
# Epoch 34/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9874 - loss: 0.0686 - val_accuracy: 0.6977 - val_loss: 0.8604
# Epoch 35/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9910 - loss: 0.0679 - val_accuracy: 0.6512 - val_loss: 0.8556
# Epoch 36/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9824 - loss: 0.0753 - val_accuracy: 0.6744 - val_loss: 0.9009
# Epoch 37/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9898 - loss: 0.0607 - val_accuracy: 0.6512 - val_loss: 0.9131
# Epoch 38/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9803 - loss: 0.0664 - val_accuracy: 0.6512 - val_loss: 0.9361
# Epoch 39/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9895 - loss: 0.0577 - val_accuracy: 0.6512 - val_loss: 0.9481
# Epoch 40/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9890 - loss: 0.0503 - val_accuracy: 0.6744 - val_loss: 0.9680
# Epoch 41/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9982 - loss: 0.0477 - val_accuracy: 0.6512 - val_loss: 0.9917
# Epoch 42/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9993 - loss: 0.0395 - val_accuracy: 0.6512 - val_loss: 1.0061
# Epoch 43/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9806 - loss: 0.0531 - val_accuracy: 0.6744 - val_loss: 1.0369
# Epoch 44/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9982 - loss: 0.0358 - val_accuracy: 0.6512 - val_loss: 1.0371
# Epoch 45/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9907 - loss: 0.0396 - val_accuracy: 0.6512 - val_loss: 1.0666
# Epoch 46/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9986 - loss: 0.0238 - val_accuracy: 0.6512 - val_loss: 1.0736
# Epoch 47/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9932 - loss: 0.0397 - val_accuracy: 0.6744 - val_loss: 1.1140
# Epoch 48/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9986 - loss: 0.0289 - val_accuracy: 0.6744 - val_loss: 1.1241
# Epoch 49/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9907 - loss: 0.0335 - val_accuracy: 0.6744 - val_loss: 1.1461
# Epoch 50/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9957 - loss: 0.0385 - val_accuracy: 0.6744 - val_loss: 1.1648
# Epoch 51/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 1.0000 - loss: 0.0310 - val_accuracy: 0.6512 - val_loss: 1.1831
# Epoch 52/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9990 - loss: 0.0238 - val_accuracy: 0.6744 - val_loss: 1.1833
# Epoch 53/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9957 - loss: 0.0240 - val_accuracy: 0.6744 - val_loss: 1.2051
# Epoch 54/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 1.0000 - loss: 0.0237 - val_accuracy: 0.6744 - val_loss: 1.2366
# Epoch 55/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 1.0000 - loss: 0.0279 - val_accuracy: 0.6744 - val_loss: 1.2457
# Epoch 56/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 1.0000 - loss: 0.0229 - val_accuracy: 0.6744 - val_loss: 1.2698
# Epoch 57/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 1.0000 - loss: 0.0174 - val_accuracy: 0.6744 - val_loss: 1.2812
# Epoch 58/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 1.0000 - loss: 0.0196 - val_accuracy: 0.6744 - val_loss: 1.3100
# Epoch 59/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 1.0000 - loss: 0.0167 - val_accuracy: 0.6744 - val_loss: 1.3236
# Epoch 60/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 1.0000 - loss: 0.0167 - val_accuracy: 0.6744 - val_loss: 1.3356
# Epoch 61/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 1.0000 - loss: 0.0229 - val_accuracy: 0.6744 - val_loss: 1.3484
# Epoch 62/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 1.0000 - loss: 0.0168 - val_accuracy: 0.6744 - val_loss: 1.3736
# Epoch 63/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 1.0000 - loss: 0.0204 - val_accuracy: 0.6744 - val_loss: 1.3862
# Epoch 64/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 1.0000 - loss: 0.0219 - val_accuracy: 0.6744 - val_loss: 1.3954
# Epoch 65/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 1.0000 - loss: 0.0139 - val_accuracy: 0.6744 - val_loss: 1.4262
# Epoch 66/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 1.0000 - loss: 0.0140 - val_accuracy: 0.6744 - val_loss: 1.4394
# Epoch 67/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 1.0000 - loss: 0.0147 - val_accuracy: 0.6744 - val_loss: 1.4546
# Epoch 68/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 1.0000 - loss: 0.0134 - val_accuracy: 0.6744 - val_loss: 1.4737
# Epoch 69/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 1.0000 - loss: 0.0168 - val_accuracy: 0.6744 - val_loss: 1.4799
# Epoch 70/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 1.0000 - loss: 0.0149 - val_accuracy: 0.6744 - val_loss: 1.5040
# Epoch 71/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 1.0000 - loss: 0.0120 - val_accuracy: 0.6744 - val_loss: 1.5108
# Epoch 72/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 1.0000 - loss: 0.0086 - val_accuracy: 0.6744 - val_loss: 1.5243
# Epoch 73/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 1.0000 - loss: 0.0106 - val_accuracy: 0.6744 - val_loss: 1.5419
# Epoch 74/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 1.0000 - loss: 0.0072 - val_accuracy: 0.6744 - val_loss: 1.5570
# Epoch 75/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 1.0000 - loss: 0.0107 - val_accuracy: 0.6744 - val_loss: 1.5710
# Epoch 76/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 1.0000 - loss: 0.0104 - val_accuracy: 0.6512 - val_loss: 1.5763
# Epoch 77/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 1.0000 - loss: 0.0117 - val_accuracy: 0.6744 - val_loss: 1.6069
# Epoch 78/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 1.0000 - loss: 0.0061 - val_accuracy: 0.6744 - val_loss: 1.6079
# Epoch 79/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 1.0000 - loss: 0.0074 - val_accuracy: 0.6512 - val_loss: 1.6188
# Epoch 80/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 1.0000 - loss: 0.0089 - val_accuracy: 0.6744 - val_loss: 1.6408
# Epoch 81/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 1.0000 - loss: 0.0069 - val_accuracy: 0.6744 - val_loss: 1.6503
# Epoch 82/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 1.0000 - loss: 0.0061 - val_accuracy: 0.6512 - val_loss: 1.6529
# Epoch 83/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 1.0000 - loss: 0.0066 - val_accuracy: 0.6744 - val_loss: 1.6739
# Epoch 84/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 1.0000 - loss: 0.0079 - val_accuracy: 0.6512 - val_loss: 1.6869
# Epoch 85/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 1.0000 - loss: 0.0052 - val_accuracy: 0.6744 - val_loss: 1.7003
# Epoch 86/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 1.0000 - loss: 0.0059 - val_accuracy: 0.6744 - val_loss: 1.7135
# Epoch 87/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 1.0000 - loss: 0.0044 - val_accuracy: 0.6512 - val_loss: 1.7247
# Epoch 88/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 1.0000 - loss: 0.0059 - val_accuracy: 0.6512 - val_loss: 1.7334
# Epoch 89/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 1.0000 - loss: 0.0055 - val_accuracy: 0.6512 - val_loss: 1.7517
# Epoch 90/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 1.0000 - loss: 0.0045 - val_accuracy: 0.6512 - val_loss: 1.7637
# Epoch 91/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 1.0000 - loss: 0.0053 - val_accuracy: 0.6512 - val_loss: 1.7747
# Epoch 92/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 1.0000 - loss: 0.0061 - val_accuracy: 0.6512 - val_loss: 1.7873
# Epoch 93/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 1.0000 - loss: 0.0053 - val_accuracy: 0.6512 - val_loss: 1.7987
# Epoch 94/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 1.0000 - loss: 0.0041 - val_accuracy: 0.6512 - val_loss: 1.7975
# Epoch 95/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 1.0000 - loss: 0.0051 - val_accuracy: 0.6512 - val_loss: 1.8205
# Epoch 96/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 1.0000 - loss: 0.0046 - val_accuracy: 0.6512 - val_loss: 1.8295
# Epoch 97/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 1.0000 - loss: 0.0042 - val_accuracy: 0.6512 - val_loss: 1.8387
# Epoch 98/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 1.0000 - loss: 0.0036 - val_accuracy: 0.6512 - val_loss: 1.8444
# Epoch 99/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 1.0000 - loss: 0.0043 - val_accuracy: 0.6512 - val_loss: 1.8588
# Epoch 100/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 1.0000 - loss: 0.0043 - val_accuracy: 0.6744 - val_loss: 1.8768

# %%
# Create the Gradio interface
interface = gr.Interface(
    fn=predict_heart_disease,
    inputs=[
        gr.Number(label="Age"),
        gr.Radio([0, 1], label="Sex (0 = Female, 1 = Male)"),
        gr.Number(label="Chest Pain Type (0-3)"),
        gr.Number(label="Resting Blood Pressure"),
        gr.Number(label="Serum Cholesterol (mg/dl)"),
        gr.Radio([0, 1], label="Fasting Blood Sugar > 120 mg/dl (1 = True, 0 = False)"),
        gr.Number(label="Resting ECG results (0-2)"),
        gr.Number(label="Max Heart Rate Achieved"),
        gr.Radio([0, 1], label="Exercise Induced Angina (1 = Yes, 0 = No)"),
        gr.Number(label="ST Depression Induced by Exercise"),
        gr.Number(label="Slope of the Peak Exercise ST Segment (0-2)"),
        gr.Number(label="Number of Major Vessels (0-3) Colored by Fluoroscopy"),
        gr.Number(label="Thalassemia (1 = Normal; 2 = Fixed Defect; 3 = Reversible Defect)")
    ],
    outputs="text",
    title="Heart Disease Prediction",
    description="Enter the patient's data to predict whether they have heart disease, including risk level."
)

# Launch the interface
interface.launch()
# Out:
# Running on local URL:  http://127.0.0.1:7865
#
# To create a public link, set `share=True` in `launch()`.
# <div><iframe src="http://127.0.0.1:7865/" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>
